# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
collections = db.list_collection_names()
for coll_name in collections:
    print(coll_name)
# Out:
# establishments

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
hygiene_20_results = list(establishments.find({"scores.Hygiene": 20}))

# Use count_documents to display the number of documents in the result
count_hygiene_20 = establishments.count_documents({"scores.Hygiene": 20})

# Display the first document in the results using pprint
first_hygiene_20 = establishments.find_one({"scores.Hygiene": 20})
pprint(first_hygiene_20)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64cf17a2705a12a8b30ada05'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
import pandas as pd
hygiene_20_df = pd.DataFrame(hygiene_20_results)

# Display the number of rows in the DataFrame
print(len(hygiene_20_df))

# Display the first 10 rows of the DataFrame
print(hygiene_20_df.head(10))
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID
# 0  64cf17a2705a12a8b30ada05   110681                  0  \
# 1  64cf17a2705a12a8b30add88   612039                  0
# 2  64cf17a2705a12a8b30ae090   730933                  0
# 3  64cf17a2705a12a8b30ae282   172735                  0
# 4  64cf17a2705a12a8b30ae28b   172953                  0
# 5  64cf17a2705a12a8b30aec2c   512854                  0
# 6  64cf17a2705a12a8b30aee59  1537089                  0
# 7  64cf17a3705a12a8b30b0375   155648                  0
# 8  64cf17a3705a12a8b30b07bf  1012883                  0
# 9  64cf17a3705a12a8b30b0fce   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName
# 0                     4029        The Chase Rest Home  \
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1
# 0                    Caring Premises               5   5-6 Southfields Road  \
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...
# 0          Eastbourne  East Sussex  ...  \
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite
# 0  http://www.eastbourne.gov.uk/foodratings  \
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress
# 0        Customerfirst@eastbourne.gov.uk  \
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS  \
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply
# 0      {'longitude': 0.27694, 'latitude': 50.769705}               \
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending
# 0  4613.888288            False  \
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta
# 0  {'dataSource': None, 'extractDate': '0001-01-0...  \
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    "$or": [
        {"AddressLine2": "London"},
        {"AddressLine3": "London"}
    ],
    "RatingValue": {"$in": ["4", "5"]}
}

# Use count_documents to display the number of documents in the result
# count_london_high_rating = establishments.count_documents({"RatingValue": "4"})
# count_london_high_rating = establishments.count_documents({"RatingValue": {"$in": ["4", "5"]}})
count_london_high_rating = establishments.count_documents(query)

# Display the first document in the results using pprint
# first_london_high_rating = establishments.find_one(query)
pprint(count_london_high_rating)
# Out:
# 1103

# %%
# Convert the result to a Pandas DataFrame
london_address_rating_results = list(establishments.find(query))
london_address_rating_df = pd.DataFrame(london_address_rating_results)

# Display the number of rows in the DataFrame
print(len(london_address_rating_df))

# Display the first 10 rows of the DataFrame
print(london_address_rating_df.head(10))
# Out:
# 1103
#                         _id   FHRSID  ChangesByServerID
# 0  64cf17a3705a12a8b30b17a1   294900                  0  \
# 1  64cf17a3705a12a8b30b29dd   329113                  0
# 2  64cf17a3705a12a8b30b29de   329114                  0
# 3  64cf17a3705a12a8b30b2b41  1402880                  0
# 4  64cf17a3705a12a8b30b2be4   975472                  0
# 5  64cf17a3705a12a8b30b2be6  1262185                  0
# 6  64cf17a3705a12a8b30b2d2e  1408389                  0
# 7  64cf17a3705a12a8b30b2d3f  1438466                  0
# 8  64cf17a3705a12a8b30b2d49  1156030                  0
# 9  64cf17a3705a12a8b30b2d54   687040                  0
#
#   LocalAuthorityBusinessID                                       BusinessName
# 0             PI/000019066                                         Mv Valulla  \
# 1         03260/0075/0/000                              The Croft Day Nursery
# 2         03260/2001/2/000                     Belvedere Sports & Social Club
# 3              21/00281/CP  Independent Catering Management At Dulverton P...
# 4              17/00162/CP                                  Abbey Good Coffee
# 5              20/00155/CP                            Chestnuts Kiosk Limited
# 6              21/00294/CP                                           Foodyz21
# 7              22/00008/CP                     Finest Chicken Peri Peri Grill
# 8             PI/000297297                                               Bona
# 9         03190/0014/0/000                                    Brownes Chemist
#
#                 BusinessType  BusinessTypeID
# 0    Other catering premises            7841  \
# 1            Caring Premises               5
# 2          Pub/bar/nightclub            7843
# 3  School/college/university            7845
# 4    Restaurant/Cafe/Canteen               1
# 5    Restaurant/Cafe/Canteen               1
# 6    Restaurant/Cafe/Canteen               1
# 7     Takeaway/sandwich shop            7844
# 8    Restaurant/Cafe/Canteen               1
# 9          Retailers - other            4613
#
#                                         AddressLine1    AddressLine2
# 0  Reeds River Cruises LtdKings ReachRiver Thames...          London  \
# 1                                   75 Woolwich Road      Abbey Wood
# 2                                 101A Woolwich Road      Abbey Wood
# 3                                   Dulverton School  Dulverton Road
# 4                                 Lesnes Abbey Lodge        New Road
# 5                                 Lesnes Abbey Lodge        New Road
# 6                                     513 Abbey Road          London
# 7                                     515 Abbey Road          London
# 8                                  25 Dartmouth Road          London
# 9                                  14-16 Wilton Road      Abbey Wood
#
#   AddressLine3  ...                              LocalAuthorityWebSite
# 0               ...  http://www.cityoflondon.gov.uk/Corporation/hom...  \
# 1       London  ...                           http://www.bexley.gov.uk
# 2       London  ...                           http://www.bexley.gov.uk
# 3       London  ...                           http://www.bexley.gov.uk
# 4       London  ...                           http://www.bexley.gov.uk
# 5       London  ...                           http://www.bexley.gov.uk
# 6               ...                           http://www.bexley.gov.uk
# 7               ...                           http://www.bexley.gov.uk
# 8               ...  http://www.lewisham.gov.uk/myservices/business...
# 9       London  ...                           http://www.bexley.gov.uk
#
#              LocalAuthorityEmailAddress
# 0  publicprotection@cityoflondon.gov.uk  \
# 1             food.safety@bexley.gov.uk
# 2             food.safety@bexley.gov.uk
# 3             food.safety@bexley.gov.uk
# 4             food.safety@bexley.gov.uk
# 5             food.safety@bexley.gov.uk
# 6             food.safety@bexley.gov.uk
# 7             food.safety@bexley.gov.uk
# 8         david.edwards@lewisham.gov.uk
# 9             food.safety@bexley.gov.uk
#
#                                               scores SchemeType
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS  \
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 7  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply
# 0     {'longitude': 0.287555, 'latitude': 51.504071}               \
# 1     {'longitude': 0.136519, 'latitude': 51.482981}
# 2     {'longitude': 0.136518, 'latitude': 51.482981}
# 3   {'longitude': 0.0809898, 'latitude': 51.4354901}
# 4  {'longitude': 0.120351999998093, 'latitude': 5...
# 5  {'longitude': 0.120351999998093, 'latitude': 5...
# 6      {'longitude': 0.121862, 'latitude': 51.48992}
# 7    {'longitude': 0.121542, 'latitude': 51.4899259}
# 8   {'longitude': 0.0143445, 'latitude': 51.3831202}
# 9      {'longitude': 0.121521, 'latitude': 51.49034}
#
#       Distance NewRatingPending
# 0  4640.460834            False  \
# 1  4645.185334            False
# 2  4645.185370            False
# 3  4645.469911            False
# 4  4645.644355            False
# 5  4645.644355            False
# 6  4645.974290            False
# 7  4645.986171            False
# 8  4645.989753            False
# 9  4646.002131            False
#
#                                                 meta
# 0  {'dataSource': None, 'extractDate': '0001-01-0...  \
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# # Search within 0.01 degree on either side of the latitude and longitude.
# import math

# # Fetch the geocoordinates of "Penang Flavours" from the list
# penang_flavours = next((e for e in establishments if e["BusinessName"] == "Penang Flavours"), None)
# if not penang_flavours:
#     raise ValueError("Penang Flavours not found in the list")

# latitude_pf = float(str(penang_flavours["geocode"]["latitude"]))
# longitude_pf = float(str(penang_flavours["geocode"]["longitude"]))

# # Filter establishments with a RatingValue of "5"
# all_establishments = [e for e in establishments if e["RatingValue"] == "5"]

# # Calculate the Euclidean distance for each establishment
# for est in all_establishments:
#     latitude_est = float(str(est["geocode"]["latitude"]))
#     longitude_est = float(str(est["geocode"]["longitude"]))
    
#     distance = math.sqrt((latitude_pf - latitude_est)**2 + (longitude_pf - longitude_est)**2)
#     est['distance'] = distance

# # Sort by distance and then by hygiene score
# sorted_establishments = sorted(
#     all_establishments, 
#     key=lambda x: (
#         x.get('distance') if x.get('distance') is not None else float('inf'), 
#         x.get('scores', {}).get('Hygiene') if x.get('scores', {}).get('Hygiene') is not None else float('inf')
#     )
# )

# # Limit to top 5
# top_5 = sorted_establishments[:5]

# # Print the results
# for r in top_5:
#     print(r)

import math

# Fetch the geocoordinates of "Penang Flavours" from the list
penang_flavours = next((e for e in establishments if e["BusinessName"] == "Penang Flavours"), None)
if not penang_flavours:
    raise ValueError("Penang Flavours not found in the list")

latitude_pf = float(str(penang_flavours["geocode"]["latitude"]))
longitude_pf = float(str(penang_flavours["geocode"]["longitude"]))

degree_search = 0.01

# Filter establishments with a RatingValue of "5" and within the range of coordinates
all_establishments = [
    e for e in establishments 
    if e["RatingValue"] == "5"
    and float(str(e["geocode"]["latitude"])) >= latitude_pf - degree_search
    and float(str(e["geocode"]["latitude"])) <= latitude_pf + degree_search
    and float(str(e["geocode"]["longitude"])) >= longitude_pf - degree_search
    and float(str(e["geocode"]["longitude"])) <= longitude_pf + degree_search
]


# Calculate the Euclidean distance for each establishment
for est in all_establishments:
    latitude_est = float(str(est["geocode"]["latitude"]))
    longitude_est = float(str(est["geocode"]["longitude"]))
    
    distance = math.sqrt((latitude_pf - latitude_est)**2 + (longitude_pf - longitude_est)**2)
    est['distance'] = distance

# Sort by distance and then by hygiene score
sorted_establishments = sorted(
    all_establishments, 
    key=lambda x: (
        x.get('distance') if x.get('distance') is not None else float('inf'), 
        x.get('scores', {}).get('Hygiene') if x.get('scores', {}).get('Hygiene') is not None else float('inf')
    )
)

# Limit to top 5
top_5 = sorted_establishments[:5]

# Print the results
for r in top_5:
    print(r)
# Out:
# {'_id': ObjectId('64cf1f54364f316ceeadbc87'), 'FHRSID': 123456, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/0000XXXXX', 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '123 Greenwich Street', 'AddressLine2': 'City Centre', 'AddressLine3': 'Greenwich', 'AddressLine4': '', 'PostCode': 'CT1 2YZ', 'Phone': '01234 567890', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2023-08-05T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Kent', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('1.076614'), 'latitude': Decimal128('51.278708')}, 'RightToReply': '', 'Distance': 0, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/123456'}], 'distance': 0.0}
# {'_id': ObjectId('64d1af1f364f316ceeadbc88'), 'FHRSID': 123456, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/0000XXXXX', 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '123 Greenwich Street', 'AddressLine2': 'City Centre', 'AddressLine3': 'Greenwich', 'AddressLine4': '', 'PostCode': 'CT1 2YZ', 'Phone': '01234 567890', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2023-08-05T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Kent', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.076614', 'latitude': '51.278708'}, 'RightToReply': '', 'Distance': 0, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/123456'}], 'distance': 0.0}
# {'_id': ObjectId('64d1c7fb364f316ceeadbc8a'), 'FHRSID': 123456, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/0000XXXXX', 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '123 Greenwich Street', 'AddressLine2': 'City Centre', 'AddressLine3': 'Greenwich', 'AddressLine4': '', 'PostCode': 'CT1 2YZ', 'Phone': '01234 567890', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2023-08-05T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Kent', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.076614', 'latitude': '51.278708'}, 'RightToReply': '', 'Distance': 0, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/123456'}], 'distance': 0.0}
# {'_id': ObjectId('64d1c9a8364f316ceeadbc8c'), 'FHRSID': 123456, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/0000XXXXX', 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': '123 Greenwich Street', 'AddressLine2': 'City Centre', 'AddressLine3': 'Greenwich', 'AddressLine4': '', 'PostCode': 'CT1 2YZ', 'Phone': '01234 567890', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2023-08-05T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Kent', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.076614', 'latitude': '51.278708'}, 'RightToReply': '', 'Distance': 0, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/123456'}], 'distance': 0.0}
# {'_id': ObjectId('64cf17a2705a12a8b30aca9f'), 'FHRSID': 1103638, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'CP/18/00181', 'BusinessName': 'The Mooring', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Water Lane Cafe', 'AddressLine2': 'Water Lane', 'AddressLine3': 'Canterbury', 'AddressLine4': 'Kent', 'PostCode': 'CT1 2NQ', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-04-11T00:00:00', 'LocalAuthorityCode': '180', 'LocalAuthorityName': 'Canterbury City', 'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk', 'LocalAuthorityEmailAddress': ' ', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('1.07705497741699'), 'latitude': Decimal128('51.2784843444824')}, 'RightToReply': '', 'Distance': 4603.383987247036, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/1103638'}], 'distance': 0.0004944520935830158}

# %%
# Convert result to Pandas DataFrame
df_establishments = pd.DataFrame(sorted_establishments)
# df_establishments.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID
# 0  64cf1f54364f316ceeadbc87   123456                  0  \
# 1  64d1af1f364f316ceeadbc88   123456                  0
# 2  64d1c7fb364f316ceeadbc8a   123456                  0
# 3  64d1c9a8364f316ceeadbc8c   123456                  0
# 4  64cf17a2705a12a8b30aca9f  1103638                  0
# 5  64cf17a2705a12a8b30acad4  1103379                  0
# 6  64cf17a2705a12a8b30acad3  1102842                  0
# 7  64cf17a2705a12a8b30aca9c  1103038                  0
# 8  64cf17a2705a12a8b30aca9b  1340744                  0
# 9  64cf17a2705a12a8b30aca8a  1128225                  0
#
#   LocalAuthorityBusinessID                                    BusinessName
# 0             PI/0000XXXXX                                 Penang Flavours  \
# 1             PI/0000XXXXX                                 Penang Flavours
# 2             PI/0000XXXXX                                 Penang Flavours
# 3             PI/0000XXXXX                                 Penang Flavours
# 4              CP/18/00181                                     The Mooring
# 5                    81749  Caterlink - St Peters Methodist Primary School
# 6                    73772       St Peters Breakfast And After School Club
# 7                    77542                                Greyfriars Lodge
# 8              CP/21/00029                                     Fond Coffee
# 9              CP/19/00070                            The Foundry Brew Pub
#
#                         BusinessType  BusinessTypeID
# 0            Restaurant/Cafe/Canteen               1  \
# 1            Restaurant/Cafe/Canteen               1
# 2            Restaurant/Cafe/Canteen               1
# 3            Restaurant/Cafe/Canteen               1
# 4            Restaurant/Cafe/Canteen               1
# 5          School/college/university            7845
# 6          School/college/university            7845
# 7  Hotel/bed & breakfast/guest house            7842
# 8            Restaurant/Cafe/Canteen               1
# 9                  Pub/bar/nightclub            7843
#
#                          AddressLine1      AddressLine2 AddressLine3  ...
# 0                123 Greenwich Street       City Centre    Greenwich  ...  \
# 1                123 Greenwich Street       City Centre    Greenwich  ...
# 2                123 Greenwich Street       City Centre    Greenwich  ...
# 3                123 Greenwich Street       City Centre    Greenwich  ...
# 4                     Water Lane Cafe        Water Lane   Canterbury  ...
# 5                    St Peter's Grove        Canterbury               ...
# 6  St Peters Methodist Primary School  St Peter's Grove   Canterbury  ...
# 7                      6 Stour Street        Canterbury               ...
# 8                      1-2 Jewry Lane        Canterbury         Kent  ...
# 9                     77 Stour Street        Canterbury         Kent  ...
#
#      LocalAuthorityEmailAddress
# 0  health@royalgreenwich.gov.uk  \
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4
# 5
# 6
# 7
# 8
# 9
#
#                                               scores SchemeType
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS  \
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply
# 0     {'longitude': 1.076614, 'latitude': 51.278708}               \
# 1  {'longitude': '1.076614', 'latitude': '51.2787...
# 2  {'longitude': '1.076614', 'latitude': '51.2787...
# 3  {'longitude': '1.076614', 'latitude': '51.2787...
# 4  {'longitude': 1.07705497741699, 'latitude': 51...
# 5  {'longitude': 1.07625102996826, 'latitude': 51...
# 6  {'longitude': 1.07625102996826, 'latitude': 51...
# 7  {'longitude': 1.07794201374054, 'latitude': 51...
# 8  {'longitude': 1.07795298099518, 'latitude': 51...
# 9   {'longitude': 1.0781913, 'latitude': 51.2787551}
#
#       Distance NewRatingPending
# 0     0.000000            False  \
# 1     0.000000            False
# 2     0.000000            False
# 3     0.000000            False
# 4  4603.383987            False
# 5  4603.468977            False
# 6  4603.468977            False
# 7  4603.382275            False
# 8  4603.381447            False
# 9  4603.352902            False
#
#                                                 meta
# 0  {'dataSource': None, 'extractDate': '0001-01-0...  \
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  distance
# 0  [{'rel': 'self', 'href': 'https://api.ratings....  0.000000
# 1  [{'rel': 'self', 'href': 'https://api.ratings....  0.000000
# 2  [{'rel': 'self', 'href': 'https://api.ratings....  0.000000
# 3  [{'rel': 'self', 'href': 'https://api.ratings....  0.000000
# 4  [{'rel': 'self', 'href': 'https://api.ratings....  0.000494
# 5  [{'rel': 'self', 'href': 'https://api.ratings....  0.001315
# 6  [{'rel': 'self', 'href': 'https://api.ratings....  0.001315
# 7  [{'rel': 'self', 'href': 'https://api.ratings....  0.001453
# 8  [{'rel': 'self', 'href': 'https://api.ratings....  0.001458
# 9  [{'rel': 'self', 'href': 'https://api.ratings....  0.001578
#
# [10 rows x 29 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Define the MongoDB collection again for some reason!
establishments_mongo = db['establishments']

# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {
        "_id": "$LocalAuthorityName", 
        "count": {"$sum": 1}
    }},
    {"$sort": {"count": -1}}
]

# Execute the aggregation pipeline on the uniquely named MongoDB collection
results = establishments_mongo.aggregate(pipeline)

# Convert the results to a list
results_list = list(results)

# Print the number of documents in the result
print(len(results_list))

# Print the first 10 results
for r in results_list[:10]:
    print(r)
# Out:
# 55
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
df_results = pd.DataFrame(results_list)

# Display the number of rows in the DataFrame
num_rows = df_results.shape[0]
print(f"Number of rows in the DataFrame: {num_rows}")

# Display the first 10 rows of the DataFrame
df_results.head(10)
# Out:
# Number of rows in the DataFrame: 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
